# %% [markdown]
# # Matplotlib

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
iris=pd.read_csv(r'E:\kiet files\4 semister\csv files\iris\iris.csv')
boston=pd.read_csv(r'E:\kiet files\4 semister\csv files\boston house\Boston.csv')
match=pd.read_csv(r'E:\kiet files\4 semister\csv files\ipl dataset\IPL Matches 2008-2020.csv')
delivery=pd.read_csv(r'E:\kiet files\4 semister\csv files\ipl dataset\IPL Ball-by-Ball 2008-2020.csv')
netflex=pd.read_csv(r'E:\kiet files\4 semister\csv files\netflix.csv')

# %%
boston.head(4)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4

# %%
# to plot line between two points

x=boston['indus']
y=boston['rad']
plt.plot(x,y)
plt.show()
# to plot line between two points with extra designs

x=boston['indus']
y=boston['rad']
plt.title("Line plot")
plt.xlabel("x.label")
plt.ylabel("y.label")
plt.plot(x,y,color='green',Linestyle=":",linewidth=4) 
plt.show()
# Out:
# <ipython-input-14-318462719947>:14: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(x,y,color='green',Linestyle=":",linewidth=4)

# %%
# two line in a single graph

x=boston['indus'] #6
y1=boston['rad'] #2
y2=boston['zn'] #1
plt.plot(x,y1,color='g',linestyle=':',linewidth=3)
plt.plot(x,y2,color='r',linestyle='-',linewidth=4)
plt.grid(True)
plt.title("Line plot")
plt.xlabel("x.label")
plt.ylabel("y.label")
plt.show()

# %%
# to understand plot function

x=boston['indus']  
y1=2*x
y2=3*x+2  
plt.plot(x,y1,color='g',linestyle=':',linewidth=3)
plt.plot(x,y2,color='r',linestyle='-',linewidth=4)
plt.grid(True)
plt.title("Line plot")
plt.xlabel("x.label")
plt.ylabel("y.label")
plt.show()

# %%
# subplot    // means two different graph in same column or row

x=boston['indus']
y1=boston['rad']
y2=boston['zn']
plt.subplot(1,2,1)

plt.plot(x,y1,color='g',linestyle=':',linewidth=3)
plt.grid(True)
plt.title("Line plot")
plt.xlabel("x.label")
plt.ylabel("y.label")

plt.subplot(1,2,2)
plt.plot(x,y2,color='r',linestyle='-',linewidth=4)
plt.grid(True)
plt.title("Line plot")
plt.xlabel("x.label")
plt.ylabel("y.label")
plt.show()

# %%
iris.head(2)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
# bar plot horizontal and vertical

x=iris['Species']  #3
y=iris['PetalLengthCm']
plt.title("Bar plot")
plt.xlabel("Species")
plt.ylabel("y.label")
plt.bar(x,y,color='red')
plt.show()

# %%
# bar plot horizontal and vertical

x=iris['Species'] 
y=iris['PetalLengthCm']
plt.barh(x,y,color='red')
# Out:
# <BarContainer object of 150 artists>

# %%
# plot scatter 

x=iris['SepalLengthCm']
y=iris['PetalLengthCm']
plt.scatter(x,y,alpha=0.5)
plt.show()


x=iris['SepalWidthCm']
y=iris['PetalLengthCm']
plt.scatter(x,y,marker="*",c='g',s=100)
plt.show()

# %%
#subplot column
x=iris['SepalWidthCm']
y=iris['PetalLengthCm']
z=iris['SepalLengthCm']
plt.subplot(2,1,1)
plt.scatter(x,y,marker="*",c='g',s=100)
plt.subplot(2,1,2)
plt.scatter(x,z,c='r',s=100,alpha=.1)  # ,alpha=.1
# x=iris['Species'] 
# y=iris['PetalLengthCm']
# plt.barh(x,y,color='red')
plt.show()

# %%
# box plot   // candle like shape
# x=iris['Species']

x=iris['SepalWidthCm']
y=iris['PetalLengthCm']

data=list([x,y])
plt.boxplot(data)
plt.show()

# Or
iris.boxplot(column=['SepalWidthCm','PetalLengthCm','SepalWidthCm'])
# Out:
# <AxesSubplot:>

# %%
# volinplot
x=iris['Species']
y=iris['SepalWidthCm']
z=iris['PetalLengthCm']
data=list([y,z])
plt.violinplot(data)
plt.show()

# iris.violinplot(column=['SepalWidthCm','PetalLengthCm'])

# %%
x=iris['Species'].unique().tolist()
y3=iris['Species'].value_counts().tolist()

print(x)

print(y3)
iris['Species'].value_counts()
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
# [50, 50, 50]
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
#pie-chart
x=iris['Species'].unique().tolist()
y3=iris['Species'].value_counts().tolist()

# x.sort()

print(y3)
print(x)
plt.pie(y3,labels=x,autopct='%0.1f%%')

plt.show()

plt.pie(y3,labels=x,autopct='%0.1f%%',colors=['yellow','grey','blue'])
plt.show()
# Out:
# [50, 50, 50]
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
# donut chart
x=iris['Species'].unique().tolist()
y3=iris['Species'].value_counts().tolist()

plt.pie(y3,labels=x,autopct='%0.1f%%',colors=['yellow','grey','blue','black'],radius=1.5)
plt.pie([1],colors=['brown'],radius=0.5)
plt.show()

# %%
boston.corr()
# 1 directly 
# -1
# Out:
#             Unnamed: 0      crim        zn     indus      chas       nox  \
# Unnamed: 0    1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736
# crim          0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972
# zn           -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604
# indus         0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651
# chas         -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203
# nox           0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000
# rm           -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188
# age           0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470
# dis          -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230
# rad           0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441
# tax           0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023
# ptratio       0.291074  0.289946 -0.391679  0.383248 -0.121515  0.188933
# ...

# %%
plt.figure(figsize=(20,8))

boston.corr().plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plt.figure(figsize=(30,15))

boston.hist(figsize=(20,15))  # column=['',''],
plt.show()

# %%
netflex.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
plt.figure(figsize=(20,10))
# x=netflex['country'].unique()[0:10].tolist()
netflex['country'].dropna().values[0:10]

countryValue=np.unique(netflex['country'].dropna().values)[0:10].tolist()
countryName=netflex['country'].value_counts()[0:10].tolist()
#country.sort()
print(countryValue)
print(y3)
plt.bar(countryValue,countryName)
# Out:
# [', France, Algeria', ', South Korea', 'Argentina', 'Argentina, Brazil, France, Poland, Germany, Denmark', 'Argentina, Chile', 'Argentina, Chile, Peru', 'Argentina, France', 'Argentina, France, United States, Germany, Qatar', 'Argentina, Italy', 'Argentina, Spain']
# [2818, 972, 419, 245, 199, 181, 145, 124, 110, 106]
# <BarContainer object of 10 artists>

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
#country=netflex['country'].value_counts()[0:10].keys()
#films=netflex['country'].value_counts()[0:10]

plt.bar(netflex['country'].value_counts()[0:10].keys(),netflex['country'].value_counts()[0:10],color='g')
plt.show()

plt.subplot(2,1,2)
plt.bar(list(netflex['country'].value_counts()[0:5].keys()),list(netflex['country'].value_counts()[0:5]),color=['blue','yellow'])
plt.show()
plt.subplot(2,2,2)
plt.figure(figsize=(7,7))
plt.pie(list(netflex['country'].value_counts()[0:5]),labels=list(netflex['country'].value_counts().keys()[0:5]),autopct='%0.1f%%')
plt.show()

# %% [markdown]
# # Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv(r'E:\kiet files\4 semister\csv files\iris\iris.csv')
boston=pd.read_csv(r'E:\kiet files\4 semister\csv files\boston house\Boston.csv')
match=pd.read_csv(r'E:\kiet files\4 semister\csv files\ipl dataset\IPL Matches 2008-2020.csv')
delivery=pd.read_csv(r'E:\kiet files\4 semister\csv files\ipl dataset\IPL Ball-by-Ball 2008-2020.csv')
netflex=pd.read_csv(r'E:\kiet files\4 semister\csv files\netflix.csv')
pokymon=pd.read_csv(r'E:\kiet files\4 semister\csv files\pokymon\pokemon.csv')

# %%
pokymon.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %% [markdown]
# ## Distribution Plots
# 1)  displot
#
# 2)  histplot
#
# 3) joint plot

# %%
iris.head(2)
# palette= Blues_d , rocket , vlag
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
sns.distplot(x=iris['SepalWidthCm'])
plt.show()
sns.distplot(x=iris['SepalWidthCm'],color='Orange',kde=True,rug=True,hist=False)
plt.show()
# Out:
# E:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# E:\anaconda\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
# displot
sns.distplot(x=iris['SepalWidthCm'])
sns.distplot(iris['SepalWidthCm'])
sns.distplot(x=iris['SepalWidthCm'],color='Orange',kde=True,rug=True,hist=False)
plt.show()
# Out:
# E:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# histplot
sns.histplot(x=iris['SepalWidthCm'])
sns.histplot(x=iris['SepalWidthCm'],color='Orange')
plt.show() 
sns.histplot(x="Sp. Atk",y='Speed',data=pokymon, hue='Legendary')
plt.show()        
#df.hist(bins=50,figsize=(20,15))

# %%
sns.jointplot(x='SepalWidthCm',y='PetalWidthCm',data=iris,kind='hex',color='blue') #kind='reg', ,kind='hex'

# %%
#Density Plots:

iris.drop(columns='Id',inplace=True)

sns.kdeplot(x=iris['PetalWidthCm'])
plt.show()
# to get all numaric dansity plot
sns.kdeplot(data=iris,bw_adjust=.5)
plt.show()

# %% [markdown]
# ## Bar plot
# 1) barplot
#
# 2) count plot
#
# 3) pairplot

# %%
sns.barplot(x='Species',y='SepalWidthCm',data=iris,palette='rocket')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
pokymon.head(2)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False

# %%
# count plot
sns.countplot(x=pokymon['Generation'])

# sns.countplot(df['Defaulted?'])
# Out:
# <AxesSubplot:xlabel='Generation', ylabel='count'>

# %%
# pairplot:
sns.pairplot(pokymon, hue='Legendary')
#   sns.pairplot(match)
#
#sns.pairplot(pokymon[['Total','Attack']].corr())

# %% [markdown]
# ## HeatMap

# %%
pokymon.corr()
# 1 directly
#b-1 indirecly
# Out:
#                    #     Total        HP    Attack   Defense   Sp. Atk  \
# #           1.000000  0.119813  0.097614  0.102298  0.094786  0.088759
# Total       0.119813  1.000000  0.618748  0.736211  0.612787  0.747250
# HP          0.097614  0.618748  1.000000  0.422386  0.239622  0.362380
# Attack      0.102298  0.736211  0.422386  1.000000  0.438687  0.396362
# Defense     0.094786  0.612787  0.239622  0.438687  1.000000  0.223549
# Sp. Atk     0.088759  0.747250  0.362380  0.396362  0.223549  1.000000
# Sp. Def     0.085817  0.717609  0.378718  0.263990  0.510747  0.506121
# Speed       0.010733  0.575943  0.175952  0.381240  0.015227  0.473018
# Generation  0.982516  0.048384  0.058683  0.051451  0.042419  0.036437
# Legendary   0.153396  0.501758  0.273620  0.345408  0.246377  0.448907
#
#              Sp. Def     Speed  Generation  Legendary
# #           0.085817  0.010733    0.982516   0.153396
# Total       0.717609  0.575943    0.048384   0.501758
# ...

# %%
# Heatmap
plt.figure(figsize=(10,6))

sns.heatmap(pokymon.corr(),square=True,fmt='.2f',annot=True,annot_kws={'size':8},cmap='Blues');# Rotate x-labels with the help of matplotlib
plt.show()
sns.heatmap(pokymon[['Total','Attack']].corr())

# sns.heatmap(iris,cbar=True, square=True,fmt='.2f',annot=True ,annot_kws={'size':8},cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
pokymon.head(2)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False

# %% [markdown]
# ## Scatter plot

# %%
#Scatter plot
#Tweaking with scatter plot
sns.lmplot(x='Sp. Atk', y='Sp. Def', data=pokymon,fit_reg = True,hue='Generation'); #Separating as per pokemon generation
# fitreg is used to Deleting regression line
plt.show()

sns.scatterplot(x='HP',y='Speed',data=pokymon,hue='Generation',palette='rocket',style='Generation')
plt.ylim(20,130);
plt.xlim(25,125);
plt.show()

from pandas.plotting import scatter_matrix
scatter_matrix(pokymon[['HP','Speed']],figsize=(12,8))
plt.ylim(20,130);
plt.xlim(25,125);
plt.show()

# %%
iris.head(2)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa

# %%
# to make scatter line density in circle
from itertools import cycle
sns.set(style="dark")

def make_kde(*args, **kwargs):    
    sns.kdeplot(*args, cmap=next(make_kde.cmap_cycle), **kwargs)

make_kde.cmap_cycle = cycle(('coolwarm', 'Wistia', 'icefire'))

our_plot = sns.PairGrid(iris, vars=('SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm'), hue='Species', dropna=True)
our_plot.map_diag(sns.kdeplot)
our_plot.map_lower(make_kde)
our_plot.map_upper(plt.scatter)
# Out:
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# E:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# word column is need to be exclude
sns.clustermap(iris[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm']])

# %%
#x.map()

ax = sns.FacetGrid(iris, col="Species", size=5)
ax.map(sns.kdeplot, "SepalWidthCm", "SepalLengthCm", hist=True,color='red' ,lw=2)
# Out:
# E:\anaconda\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# E:\anaconda\lib\site-packages\seaborn\distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'hist', 'lw'
#   cset = contour_func(
# E:\anaconda\lib\site-packages\seaborn\distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'hist', 'lw'
#   cset = contour_func(
# E:\anaconda\lib\site-packages\seaborn\distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'hist', 'lw'
#   cset = contour_func(

# %%
# # Melting our sample DataFrame: 
# sample_melt = sample.melt(id_vars=['A', 'units'], value_vars=['V_1', 'V_2'])
# 
# # Creating plot:
# ax = sns.FacetGrid(sample_melt, col='A', hue='A', palette="icefire", row='variable', sharey='row', margin_titles=True)
# ax.map(plt.plot, 'units', 'value')
# ax.add_legend()

# %% [markdown]
# ## Box plot ( candles )

# %%
# box plot (candles)
plt.figure(figsize=(20,8))
sns.boxplot(x='Type 1',y='Speed',hue='Generation',data=pokymon,linewidth=3)

#sns.boxplot(data=iris,showfliers=True);
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='Speed'>

# %% [markdown]
# ## line plot

# %%
# line plot

sns.lineplot(x='HP',y='Speed',hue='Generation',data=pokymon,palette='rocket') #   ,hue='event',style='event'
plt.show()
sns.regplot(x='HP',y='Speed',data=pokymon)
plt.show()
sns.lineplot(x='SepalLengthCm',y='PetalLengthCm',data=iris,hue='Species')
plt.show()

# %% [markdown]
# ## violen plot

# %%
# Violin plot
#sns.violinplot(x='HP',y='Speed',hue='Generation',data=pokymon)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
# Swarmplot  / stripplot
# plt.figure(figsize=(20,8))
# # sns.swarmplot(x='HP',y='Speed',hue='Generation',data=pokymon)
# sns.stripplot(x='HP',y='Speed',hue='Generation',data=pokymon)

# %%
# Overlying plot (combination of violen and Swarm plots )
plt.figure(figsize=(20,8))
sns.violinplot(x='HP',y='Generation',hue='Legendary',data=pokymon,inner=None )
sns.swarmplot(x='HP',y='Generation',hue='Legendary',data=pokymon,color='black') #making points black alpha=0.5)



sns.violinplot(x='SepalWidthCm',y='PetalWidthCm',data=iris, hue="Species",inner=None );
sns.swarmplot(x='SepalWidthCm',y='PetalWidthCm',data=iris, hue="Species",color='black')

# inner=None : Remove the bars inside the violins

# alpha=0.5: makes points slightly transparent:Remember alpha value must be float,dont keep in “”
# Out:
# E:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# E:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# E:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 61.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# E:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 73.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Factor Plots (separate swarm plot with generation like column )

factplot= sns.factorplot(x='SepalWidthCm',y='PetalWidthCm',data=iris, hue="Species",col="Species",kind="swarm");
#factplot= sns.factorplot(x="Pokemon_Type",y="Attack Strength",data=data,hue="Generation",col="Generation",kind="swarm");
factplot.set_xticklabels(rotation=-45)
# Out:
# E:\anaconda\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# E:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# E:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# E:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# # Plotly

# %%
iris.head(2)

# %%
import plotly.express as px
df = px.data.gapminder()

fig = px.scatter(pokymon.query("Generation==1"), x="Sp. Atk",y="Total",
         size="Speed",
                 hover_name="Type 1", log_x=True, size_max=60)
fig.show()

# %%
import pandas as pd
a={'name':['Hassan','Awan',"gul"]}
df=pd.DataFrame(a)

# %%
df.head(2)
# Out:
#      name
# 0  Hassan
# 1    Awan

# %%
df.to_excel('su2.xlsx',index=False)
